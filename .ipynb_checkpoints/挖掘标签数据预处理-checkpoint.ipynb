# %% [markdown]
# 处理未标签数据 对每个样本都检测时候有分类标签 如果这个样本只有一个标签 则认为这个样本是属于这个标签的

# %%
import pandas as pd
import random
import csv
from sklearn.utils import shuffle

# %%
df = pd.read_csv("./unlabeled_data.csv", engine="python", encoding="utf_8_sig")
labels = ['财经','房产','家居','教育','科技','时尚','时政','游戏','娱乐','体育']
id_list = []
label_list = []
content_list = []
neg_content_list = []
neg_id_list = []
cnt_for_game= 0
print(df)
# Out:
#           id                                            content
# 0          0  区块链正在以前所未有的速度发展。根据IDC数据，2018年中国区块链市场支出规模达1.6亿美...
# 1          1  明天就是儿童节了，连篇累牍的校园性侵事件，为我们纪念这个节日平添了沉重的注脚。当然，历史而言...
# 2          2  WTA世界排名第二的罗马尼亚名将哈勒普宣布，由于新冠肺炎疫情的蔓延，她决定不参加即将开战的美...
# 3          3  教你用几毛钱做瓷砖清洁剂，清洁阿姨都不知道！1.准备一瓶500毫升的矿泉水，倒出一半；2.取...
# 4          4  昨天，国家卫生计生委召开例行新闻发布会，围绕食品安全相关工作及社会热点答记者问。到2015年...
# ...      ...                                                ...
# 32995  32995  中新网长春4月6日电(记者崔颜锋)经吉林省政府“3.29”重大瓦斯事故调查组初步核实：吉林省...
# 32996  32996  近日，由金牌编剧董润年导演并编剧，黄渤、王珞丹、谭卓、白客、黄璐、宋春丽、文淇领衔主演，丁溪...
# 32997  32997  首先，夕阳中AnneHathaway婚纱的粉色不只是光线问题，设计稿中裙摆和头纱的下摆都是渐...
# 32998  32998  6月9日，贵州省高考评卷工作专题组长培训会在贵州师范大学举行，对今年高考评卷工作提出了严格要...
# 32999  32999  下面大宗网小编为您整理一下新股佰仁医疗(688198)的相关内容，希望对打新的小伙伴有所帮助...
#
# [33000 rows x 2 columns]

# %%
for i in range(df.shape[0]):
    count = []
    if i % 10000 ==0:
        print(i)
    for j in range(len(labels)):
        if labels[j] in df.iloc[i][1]:
            count.append(j)
    if len(count)==1:
        if count[0] == 7:
            if cnt_for_game < 1000:
                cnt_for_game += 1
                id_list.append(df.iloc[i][0])
                content_list.append(df.iloc[i][1])
                label_list.append(labels[count[0]])
        elif count[0] in [8,9]:
            id_list.append(df.iloc[i][0])
            content_list.append(df.iloc[i][1])
            label_list.append(labels[count[0]])
        else:
            neg_content_list.append(df.iloc[i][1])
            neg_id_list.append(df.iloc[i][0])
    else:
        neg_content_list.append(df.iloc[i][1])
        neg_id_list.append(df.iloc[i][0])
# Out:
# 0
# 10000
# 20000
# 30000

# %%
print(len(neg_content_list))
print(len(content_list))
# Out:
# 29320
# 2342

# %%
new_dict = {"id":id_list, "class_label":label_list, "content":content_list}
new_df = pd.DataFrame(new_dict)
print(new_df)
# Out:
#          id class_label                                            content
# 0        11          体育  纽马参赛人数最多的时候可达10万人，跑者通过标志性的纽约大吊桥时，连桥身都震动，场面很壮观。...
# 1        25          游戏  多多自走棋最近也是上新了新的棋子，而本次的这个棋子是灵族战士的岩之灵，这是一个定位为肉盾和控...
# 2        30          娱乐  现在很多新人结婚以后，都会过一场度蜜月的旅行，这样不仅能看美景，还能增进夫妻之间的感情。今天...
# 3        62          游戏  走过很多地方，去过很多景点，滑过很多场雪，只要有钱有闲谁都能来场旅行。但是下面这些地方还需要...
# 4        83          游戏  侍魂胧月传说在今天12月4日迎来了一波维护更新，值得一提的是在本次更新以后就将会迎来周年庆哦...
# ...     ...         ...                                                ...
# 2337  32897          娱乐  电影《悟空传》今日曝光了“天神合一”海报，彭于晏、倪妮、欧豪、余文乐、郑爽、乔杉、俞飞鸿纷纷...
# 2338  32903          娱乐  由小黄人团队重磅制作的动画喜剧电影《绿毛怪格林奇》于今日上映，影片在北美以超2.26亿美元成...
# 2339  32935          娱乐  近日,Marantz®对外公布了新款的PM6007合并式功放和CD6007CD播放器,专为发...
# 2340  32938          体育  9月28日，中国田径街头巡回赛2020赛季第三站在西安市大唐不夜城开元广场举行。十六朝古都西...
# 2341  32979          体育  “通过军训，锻炼了吃苦耐劳的精神，强化了祖国至上、人民至上的思想意识。我会把军训中学到的优良...
#
# [2342 rows x 3 columns]

# %%
df1 = pd.read_csv("./labeled_data.csv", engine="python", encoding="utf_8_sig")
print(df1)
data_new = pd.merge(df1, new_df, how="outer")
print(data_new.info())
# Out:
#         id class_label                                            content
# 0        0          教育  人民网北京8月31日电（孙竞）日前，为进一步规范高等学校命名工作，依据相关法律法规规定，结合...
# 1        1          家居  又是一年落叶黄，一阵秋雨一阵凉；整日奔波工作忙，出门别忘添衣裳。金秋时节，正值装修旺季，集美...
# 2        2          教育  作者：祝安顺（深圳大学饶宗颐文化研究院编审、副教授）　　越来越多的名校毕业生入职教师行业，吸...
# 3        3          时尚  虽然此前其有过与品牌如Madawell的合作系列，但这回她确认将推出自己名下的服装系列。在最...
# 4        4          教育  眼下，虽然疫情依然严峻，但我国大中小学都已陆续开学，疫情防控进入常态化，学生校园生活回归正常...
# ...    ...         ...                                                ...
# 6995  6995          教育  近期，国家卫健委发布《学校传染病症状监测预警技术指南》，其中规定，学校传染病达预警指标后，应...
# 6996  6996          房产  新冠肺炎疫情影响之下，房企纷纷开设“线上售楼处”。据克而瑞监测，目前超过150家房企在做线上...
# 6997  6997          教育  学生犯错后，教师能不能惩戒？如何惩戒？惩戒的边界在哪里？9月起，《广东省学校安全条例》（以下...
# 6998  6998          科技  6月3日下午，荣耀为我们带来了全新的荣耀Play4系列新品，包括了Play4和Play4Pr...
# 6999  6999          时政  @人民日报：【好消息速扩！天然气价格4月1日起大幅下调！】发改委今天宣布，4月1日起，我国天...
#
# [7000 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9342 entries, 0 to 9341
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9342 non-null   int64
#  1   class_label  9342 non-null   object
#  2   content      9342 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 291.9+ KB
# None

# %% [markdown]
# 数据清洗

# %%
import re
def filter(text):
    text = re.sub("[A-Za-z0-9\!\=\？\%\[\]\,\（\）\>\<:&lt;\/#\. -----\_]", "", text)
    text = text.replace('图片', '')
    text = text.replace('\xa0', '') # 删除nbsp
    # new
    r1 =  "\\【.*?】+|\\《.*?》+|\\#.*?#+|[.!/_,$&%^*()<>+""'?@|;；：　　:~{}#]+|[——！\\\，。=？、：“”‘’￥……（）《》【】]"
    cleanr = re.compile('<.*?>')
    text = re.sub(cleanr, ' ', text)        #去除html标签
    text = re.sub(r1,'',text)
    text = text.strip()
    return text

# %%
def clean_text(data):
    data['content'] = data['content'].apply(lambda x: filter(x))
    return data

# %%
data_new = clean_text(data_new)
data_new = shuffle(data_new)
print(data_new)
# Out:
#          id class_label                                            content
# 4352   4352          家居  品牌雅诗澜工艺大提花整个图案从大自然中汲取设计灵感元素取材于大自然的竹子在用线条巧妙的结合搭...
# 5395   5395          家居  孕妇怀孕期间生活方面还是要注意的平时锻炼正常可以进行比如可以做瑜伽那么孕妇瑜伽几个月可以做有...
# 8815  19975          体育  为推进大湾区体育事业和体育产业发展助力粤港澳大湾区建设月日日第二届环粤港澳大湾区城市自行车挑...
# 6075   6075          家居  有时候因各种原因婚姻关系不得不走向破裂如果有孩子那会面临孩子抚养权的问题很多人对于孩子抚养权...
# 8453  13250          游戏  由美国哥伦比亚影片公司出品的电影今日发布一支死亡幻象版正片片段再次吸引观众视线该影片在上映后...
# ...     ...         ...                                                ...
# 3140   3140          时尚  新款帝舵表不仅是一款卓越的潜水腕表更完美融合精湛工艺技术与可靠机械性能该腕表除展现多项帝舵表...
# 3817   3817          时政  整改效果怎么样整改主体责任落实的如何是不是真改实改干部群众关心的问题内蒙古自治区党委巡视工作...
# 6986   6986          时政  南粤法治报告会第九讲广州开讲全国人大常委会委员法律委员会主任委员乔晓阳贪贿犯罪最高刑罚死刑未...
# 1548   1548          财经  新一轮的债务危机已经悄然笼罩全球据媒体月日最新报道国际货币基金组织最新数据显示截至年底全球公...
# 2817   2817          财经  如何分析每股收益每股收益增加说明什么作为股票投资用户最想了解的信息就是哪些股票每股收益好只有...
#
# [9342 rows x 3 columns]

# %%
def filterLabel(text):
    return labels.index(text)
def switchLabel(data):
    data['class_label'] = data['class_label'].apply(lambda x:filterLabel(x))
    return data
data_new = switchLabel(data_new)

# %%
data_new = data_new.reset_index(drop=True)
print(data_new)
# Out:
#          id  class_label                                            content
# 0      4352            2  品牌雅诗澜工艺大提花整个图案从大自然中汲取设计灵感元素取材于大自然的竹子在用线条巧妙的结合搭...
# 1      5395            2  孕妇怀孕期间生活方面还是要注意的平时锻炼正常可以进行比如可以做瑜伽那么孕妇瑜伽几个月可以做有...
# 2     19975            9  为推进大湾区体育事业和体育产业发展助力粤港澳大湾区建设月日日第二届环粤港澳大湾区城市自行车挑...
# 3      6075            2  有时候因各种原因婚姻关系不得不走向破裂如果有孩子那会面临孩子抚养权的问题很多人对于孩子抚养权...
# 4     13250            7  由美国哥伦比亚影片公司出品的电影今日发布一支死亡幻象版正片片段再次吸引观众视线该影片在上映后...
# ...     ...          ...                                                ...
# 9337   3140            5  新款帝舵表不仅是一款卓越的潜水腕表更完美融合精湛工艺技术与可靠机械性能该腕表除展现多项帝舵表...
# 9338   3817            6  整改效果怎么样整改主体责任落实的如何是不是真改实改干部群众关心的问题内蒙古自治区党委巡视工作...
# 9339   6986            6  南粤法治报告会第九讲广州开讲全国人大常委会委员法律委员会主任委员乔晓阳贪贿犯罪最高刑罚死刑未...
# 9340   1548            0  新一轮的债务危机已经悄然笼罩全球据媒体月日最新报道国际货币基金组织最新数据显示截至年底全球公...
# 9341   2817            0  如何分析每股收益每股收益增加说明什么作为股票投资用户最想了解的信息就是哪些股票每股收益好只有...
#
# [9342 rows x 3 columns]

# %%
data_new = data_new.drop(columns=['id'])
print(data_new)
# Out:
#       class_label                                            content
# 0               2  品牌雅诗澜工艺大提花整个图案从大自然中汲取设计灵感元素取材于大自然的竹子在用线条巧妙的结合搭...
# 1               2  孕妇怀孕期间生活方面还是要注意的平时锻炼正常可以进行比如可以做瑜伽那么孕妇瑜伽几个月可以做有...
# 2               9  为推进大湾区体育事业和体育产业发展助力粤港澳大湾区建设月日日第二届环粤港澳大湾区城市自行车挑...
# 3               2  有时候因各种原因婚姻关系不得不走向破裂如果有孩子那会面临孩子抚养权的问题很多人对于孩子抚养权...
# 4               7  由美国哥伦比亚影片公司出品的电影今日发布一支死亡幻象版正片片段再次吸引观众视线该影片在上映后...
# ...           ...                                                ...
# 9337            5  新款帝舵表不仅是一款卓越的潜水腕表更完美融合精湛工艺技术与可靠机械性能该腕表除展现多项帝舵表...
# 9338            6  整改效果怎么样整改主体责任落实的如何是不是真改实改干部群众关心的问题内蒙古自治区党委巡视工作...
# 9339            6  南粤法治报告会第九讲广州开讲全国人大常委会委员法律委员会主任委员乔晓阳贪贿犯罪最高刑罚死刑未...
# 9340            0  新一轮的债务危机已经悄然笼罩全球据媒体月日最新报道国际货币基金组织最新数据显示截至年底全球公...
# 9341            0  如何分析每股收益每股收益增加说明什么作为股票投资用户最想了解的信息就是哪些股票每股收益好只有...
#
# [9342 rows x 2 columns]

# %%
data_new.to_csv('./data_train.csv', index=False, header=False)

# %% [markdown]
# 处理未标签数据

# %%
len(neg_content_list)
# Out:
# 29320

# %%
import numpy as np
neg_label_list = list(10 * np.ones(len(neg_content_list)))
print(neg_label_list)
print(len(neg_label_list))
print(len(neg_id_list))
print(len(neg_content_list))
# Out:
# [10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10. ...
# 29320
# 29320
# 29320

# %%
neg_new_dict = clean_text(data_new)

# %%
neg_new_dict = {"id":neg_id_list, "class_label":neg_label_list, "content":neg_content_list}
neg_new_df = pd.DataFrame(neg_new_dict)
neg_new_df = neg_new_df.drop(columns=['id'])
print(neg_new_df)
# Out:
#        class_label                                            content
# 0             10.0  区块链正在以前所未有的速度发展。根据IDC数据，2018年中国区块链市场支出规模达1.6亿美...
# 1             10.0  明天就是儿童节了，连篇累牍的校园性侵事件，为我们纪念这个节日平添了沉重的注脚。当然，历史而言...
# 2             10.0  WTA世界排名第二的罗马尼亚名将哈勒普宣布，由于新冠肺炎疫情的蔓延，她决定不参加即将开战的美...
# 3             10.0  教你用几毛钱做瓷砖清洁剂，清洁阿姨都不知道！1.准备一瓶500毫升的矿泉水，倒出一半；2.取...
# 4             10.0  昨天，国家卫生计生委召开例行新闻发布会，围绕食品安全相关工作及社会热点答记者问。到2015年...
# ...            ...                                                ...
# 29315         10.0  中新网长春4月6日电(记者崔颜锋)经吉林省政府“3.29”重大瓦斯事故调查组初步核实：吉林省...
# 29316         10.0  近日，由金牌编剧董润年导演并编剧，黄渤、王珞丹、谭卓、白客、黄璐、宋春丽、文淇领衔主演，丁溪...
# 29317         10.0  首先，夕阳中AnneHathaway婚纱的粉色不只是光线问题，设计稿中裙摆和头纱的下摆都是渐...
# 29318         10.0  6月9日，贵州省高考评卷工作专题组长培训会在贵州师范大学举行，对今年高考评卷工作提出了严格要...
# 29319         10.0  下面大宗网小编为您整理一下新股佰仁医疗(688198)的相关内容，希望对打新的小伙伴有所帮助...
#
# [29320 rows x 2 columns]

# %%
neg_new_df.to_csv('./data_neg.csv', index=False, header=False)

# %% [markdown]
# 读取数据

# %%
df = pd.read_csv("./data_neg.csv", engine="python", encoding="utf_8_sig")
print(df)
# Out:
#        10.0  \
# 0      10.0
# 1      10.0
# 2      10.0
# 3      10.0
# 4      10.0
# ...     ...
# 29314  10.0
# 29315  10.0
# 29316  10.0
# 29317  10.0
# 29318  10.0
#
#       区块链正在以前所未有的速度发展。根据IDC数据，2018年中国区块链市场支出规模达1.6亿美元，到2022年有望达到14.2亿美元，复合增速达到72.6%。在A股市场上，已有不少上市公司在区块链领域有所布局。日前了解到，为快速切入区块链应用赛道，恒久科技（002808）以外延并购形式收购福建省闽保信息技术股份有限公司（以下简称闽保股份）71.26%股权，在公司原有激光打印机、数码复印机的核心部件——激光有机光导鼓系列产品研发、生产与销售主营业务的基础上，加速“区块链+保密软硬件”布局。公开资料显示，2000年，我国引进了第一条OPC鼓（OPC鼓是有机照片导体的缩写）涂布生产线，开始了我国OPC鼓的产业化进程。在国家政策的支持下，经过国内企业的不断努力与创新，我国激光OPC鼓产业取得了长足的发展和显著的成就。随着市场的发展，行业内原装配套厂商与通用耗材企业之间、各通用耗材企业之间的竞争也在不断加剧，行业已发展至充分竞争阶段，不具有自主研发能力与技术创新能力的企业将被淘汰，行业优秀资源将向有显著成本、品质及技术优势的企业集中。2003年，恒久科技在国内率先以自有技术建成了一条高度自动化的高分辨力激光OPC鼓生产线，并成为国内第一家掌握高分辨力激光OPC鼓生产工艺和生产线集成技术的厂家，摆脱了过去激光OPC鼓生产只能依赖国外设备这一局面的同时也为我国激光有机光导鼓的发展掀开了新的篇章。经过多年的技术积累和生产经营，恒久科技发展成为在国内激光OPC鼓行业具备显著的技术和研发优势，也是目前世界上少数完整掌握激光OPC鼓核心技术并具备专用设备系统集成能力的企业之一，公司核心业务为激光有机光导鼓（OrganicPhoto-ConductorDrum，简称“激光OPC鼓”）系列产品的研发、生产和销售，该业务为公司的传统业务，也是公司营业收入与利润的主要来源。为了更好地开拓市场与服务客户，公司也经营碳粉、硒鼓以及其他打复印耗材的国际与国内贸易业务。为提高产品品质、延伸产品使用领域，近日恒久科技与闽保股份实际控制人林章威签署了《股权收购协议》，恒久科技以支付现金的方式出资约1.4亿元购买林章威所持有的标的公司2289.7万股股份，实现对闽保股份的控股。交易完成后，公司将依托闽保股份多年来在信息安全和系统集成领域的技术成果以及较强的软件开发能力，进一步加强公司产品的保密性和安全性，增强公司在打印机、复印机和数码快印以及云共享等影像产业领域的综合竞争力。提及本次与恒久科技的合作，闽保股份方面在接受《证券日报》记者采访时表示，双方的合作是一次优势互补的过程，恒久科技是一家生产打印机耗材的公司，借力恒久科技的优势，闽保股份将投入研发打印机和增强型安全打印机，同时结合公司自身保密特点，研发保密会议室系统和保密手机系统。据了解，总体来看，我国信息安全产业投入占IT总投入比重相对较小、行业成长空间大。数据显示，2018年我国信息安全市场规模超500亿元。初步预计随着信息安全的进一步普及、应用，未来市场规模将不断扩大，预计2019年中国信息安全市场规模将近620亿元。“未来3年-5年公司将利用上市公司的多种资源，不断扩大在区块链技术与实体经济融合领域中的参与度。”闽保股份方面表示下一步公司将在加快对办公软件加密技术传输、计算机及移动存储介质保密管理系统、移动数据安全防护系统、网络存储安全增强系统方面发力。
# 0      明天就是儿童节了，连篇累牍的校园性侵事件，为我们纪念这个节日平添了沉重的注脚。当然，历史而言...
# 1      WTA世界排名第二的罗马尼亚名将哈勒普宣布，由于新冠肺炎疫情的蔓延，她决定不参加即将开战的美...
# 2      教你用几毛钱做瓷砖清洁剂，清洁阿姨都不知道！1.准备一瓶500毫升的矿泉水，倒出一半；2.取...
# 3      昨天，国家卫生计生委召开例行新闻发布会，围绕食品安全相关工作及社会热点答记者问。到2015年...
# 4      忍者学园中玩家们可以进行PVE模式的刷图，而在副本中也是有着很多的BOSS在等着玩家们去攻略...
# ...                                                  ...
# 29314  中新网长春4月6日电(记者崔颜锋)经吉林省政府“3.29”重大瓦斯事故调查组初步核实：吉林省...
# 29315  近日，由金牌编剧董润年导演并编剧，黄渤、王珞丹、谭卓、白客、黄璐、宋春丽、文淇领衔主演，丁溪...
# 29316  首先，夕阳中AnneHathaway婚纱的粉色不只是光线问题，设计稿中裙摆和头纱的下摆都是渐...
# 29317  6月9日，贵州省高考评卷工作专题组长培训会在贵州师范大学举行，对今年高考评卷工作提出了严格要...
# 29318  下面大宗网小编为您整理一下新股佰仁医疗(688198)的相关内容，希望对打新的小伙伴有所帮助...
#
# [29319 rows x 2 columns]

# %%
select_df = df.sample(1000)
print(select_df)
# Out:
#        10.0  \
# 19123  10.0
# 9960   10.0
# 28593  10.0
# 11705  10.0
# 1303   10.0
# ...     ...
# 1457   10.0
# 7749   10.0
# 28972  10.0
# 27979  10.0
# 13271  10.0
#
#       区块链正在以前所未有的速度发展。根据IDC数据，2018年中国区块链市场支出规模达1.6亿美元，到2022年有望达到14.2亿美元，复合增速达到72.6%。在A股市场上，已有不少上市公司在区块链领域有所布局。日前了解到，为快速切入区块链应用赛道，恒久科技（002808）以外延并购形式收购福建省闽保信息技术股份有限公司（以下简称闽保股份）71.26%股权，在公司原有激光打印机、数码复印机的核心部件——激光有机光导鼓系列产品研发、生产与销售主营业务的基础上，加速“区块链+保密软硬件”布局。公开资料显示，2000年，我国引进了第一条OPC鼓（OPC鼓是有机照片导体的缩写）涂布生产线，开始了我国OPC鼓的产业化进程。在国家政策的支持下，经过国内企业的不断努力与创新，我国激光OPC鼓产业取得了长足的发展和显著的成就。随着市场的发展，行业内原装配套厂商与通用耗材企业之间、各通用耗材企业之间的竞争也在不断加剧，行业已发展至充分竞争阶段，不具有自主研发能力与技术创新能力的企业将被淘汰，行业优秀资源将向有显著成本、品质及技术优势的企业集中。2003年，恒久科技在国内率先以自有技术建成了一条高度自动化的高分辨力激光OPC鼓生产线，并成为国内第一家掌握高分辨力激光OPC鼓生产工艺和生产线集成技术的厂家，摆脱了过去激光OPC鼓生产只能依赖国外设备这一局面的同时也为我国激光有机光导鼓的发展掀开了新的篇章。经过多年的技术积累和生产经营，恒久科技发展成为在国内激光OPC鼓行业具备显著的技术和研发优势，也是目前世界上少数完整掌握激光OPC鼓核心技术并具备专用设备系统集成能力的企业之一，公司核心业务为激光有机光导鼓（OrganicPhoto-ConductorDrum，简称“激光OPC鼓”）系列产品的研发、生产和销售，该业务为公司的传统业务，也是公司营业收入与利润的主要来源。为了更好地开拓市场与服务客户，公司也经营碳粉、硒鼓以及其他打复印耗材的国际与国内贸易业务。为提高产品品质、延伸产品使用领域，近日恒久科技与闽保股份实际控制人林章威签署了《股权收购协议》，恒久科技以支付现金的方式出资约1.4亿元购买林章威所持有的标的公司2289.7万股股份，实现对闽保股份的控股。交易完成后，公司将依托闽保股份多年来在信息安全和系统集成领域的技术成果以及较强的软件开发能力，进一步加强公司产品的保密性和安全性，增强公司在打印机、复印机和数码快印以及云共享等影像产业领域的综合竞争力。提及本次与恒久科技的合作，闽保股份方面在接受《证券日报》记者采访时表示，双方的合作是一次优势互补的过程，恒久科技是一家生产打印机耗材的公司，借力恒久科技的优势，闽保股份将投入研发打印机和增强型安全打印机，同时结合公司自身保密特点，研发保密会议室系统和保密手机系统。据了解，总体来看，我国信息安全产业投入占IT总投入比重相对较小、行业成长空间大。数据显示，2018年我国信息安全市场规模超500亿元。初步预计随着信息安全的进一步普及、应用，未来市场规模将不断扩大，预计2019年中国信息安全市场规模将近620亿元。“未来3年-5年公司将利用上市公司的多种资源，不断扩大在区块链技术与实体经济融合领域中的参与度。”闽保股份方面表示下一步公司将在加快对办公软件加密技术传输、计算机及移动存储介质保密管理系统、移动数据安全防护系统、网络存储安全增强系统方面发力。
# 19123  随着时代的不断发展，居民的生活条件也在不断改善。每个人都希望获得一个更好的生活环境。然而，房...
# 9960   北京时间8月23日消息，2019-2020中国男排超级联赛重启第二阶段八强战第一轮开战，上届...
# 28593  习近平近日作出批示，要求广大干部群众厉行节约，反对浪费。节约之风已由中国最高层推动，逐渐吹向...
# 11705  北京时间8月25日消息，辛辛那提大师赛，德约科维奇战胜了比兰基斯，今年保持19场不败纪录也豪...
# 1303   ­　　浙江省政府办公厅近日发布《2017年浙江省食品安全工作要点》，提出将完善食品安全督查考...
# ...                                                  ...
# 1457   首开住总熙悦安郡雄踞北京内城稀缺之地。围绕北京内城，洋溢着中国地域中贵族般的卓越之气，匹配高...
# 7749   为了能够让更多人一同感受到美丽星空所带来的感动，vivo在广州公园前地铁站开设了X50系列的...
# 28972  “理解马的行为”是一个复杂的探索之旅，需要你不断思索，不断向自己提出更多疑问，才能寻求到答案...
# 27979  Balmain裙装谁穿最有型作者：何静时间：2013年5月23日内容来源：VOGUE时尚网 ...
# 13271  食物语中有很多的副本在等着玩家们去挑战，比如这个协会中就是有着很多的BOSS的，那么面对这些...
#
# [1000 rows x 2 columns]

# %%
df3 = pd.read_csv("./data_train.csv", engine="python", encoding="utf_8_sig")
print(df3)
# Out:
#       2  \
# 0     2
# 1     9
# 2     2
# 3     7
# 4     7
# ...  ..
# 9336  5
# 9337  6
# 9338  6
# 9339  0
# 9340  0
#
#      品牌雅诗澜工艺大提花整个图案从大自然中汲取设计灵感元素取材于大自然的竹子在用线条巧妙的结合搭配虽不一定要染满自然的色彩却要褪尽都市的痕迹远离谋生之累进入清静之境表现大自然永恒的魅力它更像一种体验使人们的内心充满宁静与舒适触发对自然与朴实的向往亲切温馨大方通过材质本身的肌理感与质感让居者更能亲近的感受自然的呵护从心理上摆脱现代都市生活的暄嚣让家居空间保有持久的魅力品牌雅诗澜工艺大提花现代简约工业风线条新潮流畅简洁大方简朴而又不失特色线条非对称图案抽象图案等等组成由于线条简单装饰元素少线条需要突出流畅的特征更加凸显个性张扬自我无常规的空间拼接以及对黑白灰的强烈对比运用刚柔并济的选材搭配以及混搭的风格手法从冷峻寻求到一种超现实的平衡让人感觉眼前一亮非常有个性具有新潮时尚的特质随意轻松的居室环境越来越多的都城人开始摒弃繁琐豪华的装修力求拥有一种自然简约的居室空间以简洁的表现形式来满足人们间环境那种感性的本能的和理性的需求品牌雅诗澜工艺大提花家居设计中经常使用一些自然材质的肌理和色彩浅淡色彩简洁装饰将空间里多余的东西简化留下最基本的设计和功能需求赋予人更多的想象空间通过提花织造来表现材质本身的肌理感与质感让家居空间保有持久的魅力把纹理设计纱线选择色彩搭配做到完美统一面料采用高纬密色纺纱织造细腻柔软光滑疏密有致的纹理和细腻光滑的质感相撞凸显出婉约清丽的极致简约品牌雅诗澜工艺大提花现代简约风格线条新潮流畅简洁大方简朴而又不失特色线条非对称图案抽象图案等等组成由于线条简单装饰元素少线条需要突出流畅的特征更加凸显个性张扬自我无常规的空间拼接以及对经典蓝与白色的强烈对比运用手法从冷峻寻求到一种超现实的平衡让人感觉眼前一亮非常有个性具有新潮时尚的特质原文网址新浪精选雅诗澜
# 0     孕妇怀孕期间生活方面还是要注意的平时锻炼正常可以进行比如可以做瑜伽那么孕妇瑜伽几个月可以做有...
# 1     为推进大湾区体育事业和体育产业发展助力粤港澳大湾区建设月日日第二届环粤港澳大湾区城市自行车挑...
# 2     有时候因各种原因婚姻关系不得不走向破裂如果有孩子那会面临孩子抚养权的问题很多人对于孩子抚养权...
# 3     由美国哥伦比亚影片公司出品的电影今日发布一支死亡幻象版正片片段再次吸引观众视线该影片在上映后...
# 4     月日下午红米正式发布了系列手机除了外官方还给我们带来了版该机搭载处理器后置万像素超清四摄像头...
# ...                                                 ...
# 9336  新款帝舵表不仅是一款卓越的潜水腕表更完美融合精湛工艺技术与可靠机械性能该腕表除展现多项帝舵表...
# 9337  整改效果怎么样整改主体责任落实的如何是不是真改实改干部群众关心的问题内蒙古自治区党委巡视工作...
# 9338  南粤法治报告会第九讲广州开讲全国人大常委会委员法律委员会主任委员乔晓阳贪贿犯罪最高刑罚死刑未...
# 9339  新一轮的债务危机已经悄然笼罩全球据媒体月日最新报道国际货币基金组织最新数据显示截至年底全球公...
# 9340  如何分析每股收益每股收益增加说明什么作为股票投资用户最想了解的信息就是哪些股票每股收益好只有...
#
# [9341 rows x 2 columns]
